# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
#creating a new column family using Siblings and children
df["Family"] = df["SibSp"]+df["Parch"]
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  Family
# 0            1         0       3  ...   NaN        S       1
# 1            2         1       1  ...   C85        C       1
#
# [2 rows x 13 columns]

# %%
#Ticket ---> As it is just a random number ,we canskip column for analsis
df.Family.describe()
# Out:
# count    891.000000
# mean       0.904602
# std        1.613459
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max       10.000000
# Name: Family, dtype: float64

# %%
#Based on the categories,we will analyse which category people were most likely to survive
#low,mid,mid high,high
df["Fare_Category"] = pd.cut(df.Fare,bins=[0,7.9,14.45,31.00,512],
                             labels=["Low","Mid","Mid-High","High"])
df["Fare_Category"].head()
# Out:
# 0     Low
# 1    High
# 2     Mid
# 3    High
# 4     Mid
# Name: Fare_Category, dtype: category
# Categories (4, object): [Low < Mid < Mid-High < High]

# %%
df.drop("Fare_category",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-171-393382cfcc8f> in <module>()
# ----> 1 df.drop("Fare_category",axis=1,inplace=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
#comparing fare with fare category
df[["Fare","Fare_Category"]]
# Out:
#         Fare Fare_Category
# 0     7.2500           Low
# 1    71.2833          High
# 2     7.9250           Mid
# 3    53.1000          High
# 4     8.0500           Mid
# ..       ...           ...
# 886  13.0000           Mid
# 887  30.0000      Mid-High
# 888  23.4500      Mid-High
# 889  30.0000      Mid-High
# 890   7.7500           Low
#
# [891 rows x 2 columns]

# %%
#Visualize Fare category
# Countplot give
sns.countplot(x="Fare_Category",data=df)

# %%
#Visulizing the count of categories based on survived
sns.countplot(x="Fare_Category",hue="Survived",data=df)

# %%
#Visulizing the count of categories based on survived
plt.figure(figsize=(8,8))
sns.countplot(x="Fare_Category",hue="Survived",data=df).\
            set_title("Survival based on Fare category")
# Out:
# Text(0.5, 1.0, 'Survival based on Fare category')

# %% [markdown]
# + We can observe that the chances of survival for people under high fare category are increasing as fare increases

# %%
#Boarding port(Embarked port)
df.Embarked.value_counts(normalize=True)*100
# Out:
# S    72.440945
# C    18.897638
# Q     8.661417
# Name: Embarked, dtype: float64

# %%
#visualizing port column
sns.countplot(x="Embarked",data=df)

# %%
p = sns.countplot(x="Embarked",data=df,hue="Survived")
#visulaizing port column using survived

# %%
p = sns.countplot(x="Embarked",data=df,hue="Survived")
p.set_title("Survival Vs port")
p.set_xticklabels(["Southampton","Chebourg","Queestown"])
p.legend(labels=["Deceased","Survived"])

# %%
#imputing with missing values
df.isnull().mean().sort_values(ascending=False)
# Out:
# Cabin            0.771044
# Age              0.198653
# Fare_Category    0.020202
# Embarked         0.002245
# Family           0.000000
# Fare             0.000000
# Ticket           0.000000
# Parch            0.000000
# SibSp            0.000000
# Sex              0.000000
# Name             0.000000
# Pclass           0.000000
# Survived         0.000000
# PassengerId      0.000000
# dtype: float64

# %%
#Cabin --> 77% missing values,creating a new category as NA
df.Cabin.fillna("NA",inplace=True)

# %%
df.Cabin.isna().sum()
# Out:
# 0

# %%
df.Age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
df.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
#filling median in age column of nan
df.Age.fillna(df.Age.median(),inplace=True)
df.Age.isnull().sum()
# Out:
# 0

# %%
# imputing embarked with mode
df.Embarked.fillna(df.Embarked.mode()[0],inplace=True)
df.Embarked.isnull().sum()
# Out:
# 0

# %%
#imputing farecategory with mode
df.Fare_Category.fillna(df.Fare_Category.mode()[0],inplace=True)
df.Fare_Category.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         0
# Family           0
# Fare_Category    0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ... Embarked Family  Fare_Category
# 0            1         0       3  ...        S      1            Low
# 1            2         1       1  ...        C      1           High
# 2            3         1       3  ...        S      0            Mid
# 3            4         1       1  ...        S      1           High
# 4            5         0       3  ...        S      0            Mid
#
# [5 rows x 14 columns]

# %%
df["Age-range"]= pd.cut(df.Age,[0,10,20,30,40,60,80])
df[["Age","Age-range"]].head()
# Out:
#     Age Age-range
# 0  22.0  (20, 30]
# 1  38.0  (30, 40]
# 2  26.0  (20, 30]
# 3  35.0  (30, 40]
# 4  35.0  (30, 40]

# %%
#Encoding all at once
df = pd.concat([df,pd.get_dummies(df.Cabin,prefix="Cabin",drop_first=True),
                    pd.get_dummies(df.Embarked,prefix="Emb",drop_first=True),
                    pd.get_dummies(df.Fare_Category,prefix="Fare",drop_first=True),
                    pd.get_dummies(df["Age-range"],drop_first=True)],axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ... (30, 40] (40, 60]  (60, 80]
# 0              1         0       3  ...        0        0         0
# 1              2         1       1  ...        1        0         0
# 2              3         1       3  ...        0        0         0
# 3              4         1       1  ...        1        0         0
# 4              5         0       3  ...        1        0         0
# ..           ...       ...     ...  ...      ...      ...       ...
# 886          887         0       2  ...        0        0         0
# 887          888         1       1  ...        0        0         0
# 888          889         0       3  ...        0        0         0
# 889          890         1       1  ...        0        0         0
# 890          891         0       3  ...        1        0         0
#
# [891 rows x 172 columns]

# %%
#Encoding sex column with label encoder
from sklearn.preprocessing import LabelEncoder
df["Sex"]=LabelEncoder().fit_transform(df.Sex)
df.head()
# Out:
#    PassengerId  Survived  Pclass  ... (30, 40]  (40, 60]  (60, 80]
# 0            1         0       3  ...        0         0         0
# 1            2         1       1  ...        1         0         0
# 2            3         1       3  ...        0         0         0
# 3            4         1       1  ...        1         0         0
# 4            5         0       3  ...        1         0         0
#
# [5 rows x 172 columns]

# %%
#droping unnecessary columns
df.drop(["PassengerId","Name","Age","SibSp","Parch","Ticket","Embarked","Fare","Fare_Category","Cabin","Age-range"],axis=1,inplace=True)

# %%
df.shape
# Out:
# (891, 161)

# %%
df.dtypes
# Out:
# Survived     int64
# Pclass       int64
# Sex          int64
# Family       int64
# Cabin_A14    uint8
#              ...
# (10, 20]     uint8
# (20, 30]     uint8
# (30, 40]     uint8
# (40, 60]     uint8
# (60, 80]     uint8
# Length: 161, dtype: object

# %%
# Seperating input and output data,dropping survival column
X = df.drop("Survived",axis=1)
X.shape
# Out:
# (891, 160)

# %%
# Output column
y = df.iloc[:,0]
y.shape
# Out:
# (891,)

# %%
#seperate i/o into training and testing
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=1)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (668, 160)
# (223, 160)
# (668,)
# (223,)
